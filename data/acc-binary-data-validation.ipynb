# %%
import struct

with open('GCAM1-ACC1-2020-0414-172950','rb') as file:
    bytes_data=file.read()
a = []
for i in range(500):
    a.append(struct.unpack('<ddd',bytes_data[24*i:24*(i+1)]))
    
from matplotlib.pyplot import *

figure(1)
plot(b)
show()
